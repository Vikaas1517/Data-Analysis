# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikaas1517/Data-Analysis/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
d1 = pd.read_csv("/content/drive/MyDrive/i1.csv")
d2 = pd.read_csv("/content/drive/MyDrive/i2.csv")

# %%
d1.head()
# Out:
#          Date            Timestamp  Invoice No.             Item Name  Price  \
# 0  2023-09-19  2023-09-19 22:03:44        28389                Kulcha   55.0
# 1  2023-09-19  2023-09-19 22:03:44        28389                Parota   30.0
# 2  2023-09-19  2023-09-19 22:03:44        28389       Mushroom Masala  150.0
# 3  2023-09-19  2023-09-19 22:03:44        28389  Paneer Butter Masala  150.0
# 4  2023-09-19  2023-09-19 22:03:44        28389              Gobi- 65  120.0
#
#    Qty.  Sub Total  Discount   Tax  Final Total  Table No. Server Name  \
# 0   1.0       55.0       0.0  2.76        57.76         16      biller
# 1   4.0      120.0       0.0  6.00       126.00         16      biller
# 2   1.0      150.0       0.0  7.50       157.50         16      biller
# 3   1.0      150.0       0.0  7.50       157.50         16      biller
# 4   1.0      120.0       0.0  6.00       126.00         16      biller
#
#    Covers Variation       Category  HSN
# ...

# %%
d2.head()
# Out:
#          Date            Timestamp  Invoice No.        Item Name  Price  Qty.  \
# 0  2023-06-30  2023-06-30 22:47:50        26190    Mineral Water   20.0   1.0
# 1  2023-06-30  2023-06-30 22:25:11        26189  Chapathi (2 No)   50.0   1.0
# 2  2023-06-30  2023-06-30 22:25:11        26189             Roti   40.0   1.0
# 3  2023-06-30  2023-06-30 22:25:11        26189   Mushroom Pulao  140.0   1.0
# 4  2023-06-30  2023-06-30 22:25:11        26189   Veg Fried Rice  130.0   1.0
#
#    Sub Total  Discount  Tax  Final Total  Table No. Server Name  Covers  \
# 0       20.0       0.0  1.0         21.0        1.0      biller       0
# 1       50.0       0.0  2.5         52.5        9.0      biller       0
# 2       40.0       0.0  2.0         42.0        9.0      biller       0
# 3      140.0       0.0  7.0        147.0        9.0      biller       0
# 4      130.0       0.0  6.5        136.5        9.0      biller       0
#
#   Variation             Category  HSN
# ...

# %%
data=d1.merge(d2,how='outer')

# %%
data.head()
# Out:
#          Date            Timestamp  Invoice No.                    Item Name  \
# 0  2023-04-01  2023-04-01 13:16:03        23465          Babycorn Manchurian
# 1  2023-04-01  2023-04-01 13:16:03        23465            Chicken Kati Roll
# 2  2023-04-01  2023-04-01 13:16:03        23465         Paneer Butter Masala
# 3  2023-04-01  2023-04-01 13:16:03        23465                 Pulka (2 No)
# 4  2023-04-01  2023-04-01 13:16:03        23465  Schewan  Chicken Fried Rice
#
#    Price  Qty.  Sub Total  Discount   Tax  Final Total  Table No. Server Name  \
# 0  160.0   1.0      160.0       0.0   8.0        168.0       20.0      biller
# 1  120.0   1.0      120.0       0.0   6.0        126.0       20.0      biller
# 2  150.0   2.0      300.0       0.0  15.0        315.0       20.0      biller
# 3   40.0   3.0      120.0       0.0   6.0        126.0       20.0      biller
# 4  160.0   1.0      160.0       0.0   8.0        168.0       20.0      biller
#
# ...

# %%
data.shape
# Out:
# (15621, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15621 entries, 0 to 15620
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         15621 non-null  object
#  1   Timestamp    15621 non-null  object
#  2   Invoice No.  15621 non-null  int64
#  3   Item Name    15621 non-null  object
#  4   Price        15621 non-null  float64
#  5   Qty.         15621 non-null  float64
#  6   Sub Total    15621 non-null  float64
#  7   Discount     15621 non-null  float64
#  8   Tax          15621 non-null  float64
#  9   Final Total  15621 non-null  float64
#  10  Table No.    15613 non-null  float64
#  11  Server Name  15621 non-null  object
#  12  Covers       15621 non-null  int64
#  13  Variation    15 non-null     object
#  14  Category     15621 non-null  object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
data.isna().sum()
# Out:
# Date               0
# Timestamp          0
# Invoice No.        0
# Item Name          0
# Price              0
# Qty.               0
# Sub Total          0
# Discount           0
# Tax                0
# Final Total        0
# Table No.          8
# Server Name        0
# Covers             0
# Variation      15606
# Category           0
# HSN            15621
# dtype: int64

# %%
data["Invoice No."].unique()
# Out:
# array([23465, 23466, 23467, ..., 28387, 28388, 28389])

# %%
data["Invoice No."].nunique()
# Out:
# 4925

# %%
data["Final Total"].sum()
# Out:
# np.float64(2397010.12)

# %%
data["Final Total"].sum()/data["Invoice No."].nunique()
# Out:
# np.float64(486.70256243654825)

# %%
invoice_totals = data.groupby(
    ["Invoice No."]
)

# %%
data.groupby("Invoice No.")["Final Total"].sum().loc[28327]
# Out:
# np.float64(1081.5)

# %%
data["Qty."].sum()
# Out:
# np.float64(20914.0)

# %%
item_qty=data.groupby("Item Name")["Qty."].sum().sort_values(ascending=False)[0:5]
item_qty
# Out:
# Item Name
# Mineral Water                             1672.0
# Chicken Biriyani With Raitha And Gravy    1453.0
# Butter Naan                               1046.0
# Romali Roti (1 No)                         822.0
# Lemon Soda                                 722.0
# Name: Qty., dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x=item_qty.index, height=item_qty.values)
plt.xlabel('Item Name')
plt.ylabel('Quantity Sold')
plt.title('Top 5 Most Sold Items')
plt.show()

# %%
item_rev=data.groupby("Item Name")["Final Total"].sum().sort_values(ascending=False)[0:5]
item_rev
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    240730.96
# Chicken Fried Rice                        119347.20
# Butter Naan                                65387.74
# Thandoor Chicken Half                      53185.83
# Paneer Butter Masala                       49581.22
# Name: Final Total, dtype: float64

# %%
data.groupby("Date")["Invoice No."].loc['2023-09-14']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1097502256.py in <cell line: 0>()
# ----> 1 data.groupby("Date")["Invoice No."].loc['2023-09-14']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#    1361             return self[attr]
#    1362
# -> 1363         raise AttributeError(
#    1364             f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'loc'

# %%
data[data['Date']=='14.09.2023']
# Out:
#             Date            Timestamp  Invoice No.                Item Name  \
# 14980 2023-09-14  2023-09-14 13:27:37        28192  Masala Omelet (two Eggs
# 14981 2023-09-14  2023-09-14 13:27:37        28192     Paneer Butter Masala
# 14982 2023-09-14  2023-09-14 13:27:37        28192       Romali Roti (1 No)
# 14983 2023-09-14  2023-09-14 13:31:07        28193           Veg Fried Rice
# 14984 2023-09-14  2023-09-14 13:31:52        28194            Mineral Water
# ...          ...                  ...          ...                      ...
# 15065 2023-09-14  2023-09-14 22:15:03        28221              Butter Naan
# 15066 2023-09-14  2023-09-14 22:15:03        28221        Chappathi (1 No.)
# 15067 2023-09-14  2023-09-14 22:15:03        28221  Chicken Chettinad Gravy
# 15068 2023-09-14  2023-09-14 22:15:03        28221       Chicken Fried Rice
# 15069 2023-09-14  2023-09-14 22:15:03        28221         Soft Drink 250ml
#
# ...

# %%
Total_avg=data.groupby("Invoice No.")["Final Total"].sum().mean()
Total_avg
# Out:
# np.float64(486.70256243654825)

# %%
Avg=data.groupby("Invoice No.")["Final Total"].sum()
Avg
# Out:
# Invoice No.
# 23465    1134.00
# 23466     441.00
# 23467     774.88
# 23468     273.00
# 23469     462.00
#           ...
# 28385     493.50
# 28386    1479.44
# 28387    1501.50
# 28388    1928.82
# 28389     666.76
# Name: Final Total, Length: 4925, dtype: float64

# %%
Count = Avg > Total_avg
Count.sum()
# Out:
# np.int64(1458)
